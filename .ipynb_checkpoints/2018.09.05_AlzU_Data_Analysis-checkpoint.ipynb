# %%
import pandas as pd

# %%
ALZU_RESPONSES_FILE_PATH = '../Data_Folder/2018.09.18_AlzU_ANU-DRI + Responses_Numerical.csv'

# %% [markdown]
# ## Combine first two rows to generate column names

# %%
two_header_rows = pd.read_csv(ALZU_RESPONSES_FILE_PATH, header=None, nrows = 2, delimiter = ",", keep_default_na=False)

transformed_header_row = []

most_recent_col_first_row = None
for column in two_header_rows:
    primary_header = two_header_rows[column][0]
    sub_header = two_header_rows[column][1]
#     print(primary_header + ": " + sub_header)
    if(primary_header != ""):
        most_recent_col_first_row = primary_header
    transformed_header_row.append(most_recent_col_first_row + ": " + sub_header)
# Out:
#              0             1           2         3           4    \
# 0  Respondent ID  Collector ID  Start Date  End Date  IP Address
# 1
#
#              5           6          7              8    \
# 0  Email Address  First Name  Last Name  Custom Data 1
# 1
#
#                                               9           ...           \
# 0  How many lessons did you complete on AlzU.org?         ...
# 1                                        Response         ...
#
#                                                  119  \
# 0  How many drinks do you have on a typical day w...
# 1                                           Response
#
#                                                  120  \
# 0  Do you, or have you ever, smoked cigarettes, c...
# 1                                           Response
#
#                                                  121  \
# 0  Have you ever been involved in occupations tha...
# 1                                           Response
#
#                                                  122  \
# 0  On average, how many hours per night do you sl...
# 1                                Open-Ended Response
#
#                                                  123  \
# 0  Write a short sketch about a memory from your ...
# 1                                Open-Ended Response
#
#                                                  124                  125  \
# 0  How does technology and social media impact th...                  uid
# 1                                Open-Ended Response  Open-Ended Response
#
#                    126                  127                  128
# 0               joined                email                   lc
# 1  Open-Ended Response  Open-Ended Response  Open-Ended Response
#
# [2 rows x 129 columns]

# %% [markdown]
# ## Load Data with column names

# %%
# indices_to_skip = np.array([0,1])
data = pd.read_csv(ALZU_RESPONSES_FILE_PATH, header=None, skiprows = [0,1], delimiter = ",", keep_default_na=False, names=transformed_header_row)

print(data.shape)
print(len(transformed_header_row))
data.head()
# Out:
# (1458, 129)
# 129
#    Respondent ID:   Collector ID:          Start Date:            End Date:   \
# 0       6936062570       170620047   2018-09-05 9:46:59   2018-09-05 9:50:09
# 1       6935898635       170620047  2018-09-04 20:43:46  2018-09-04 22:55:52
# 2       6935793919       170620047  2018-09-04 16:23:38  2018-09-04 16:26:34
# 3       6935733915       170620047  2018-09-04 14:10:18  2018-09-04 14:27:56
# 4       6935603649       170620047   2018-09-04 9:27:18  2018-09-04 10:48:34
#
#      IP Address:  Email Address:  First Name:  Last Name:  Custom Data 1:   \
# 0  72.239.164.168
# 1   73.230.13.240
# 2   98.155.32.231
# 3     12.33.32.71
# 4   160.2.106.111
#
#   How many lessons did you complete on AlzU.org?: Response  \
# 0                                                  3
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#             ...            \
# 0           ...
# 1           ...
# 2           ...
# 3           ...
# 4           ...
#
#   How many drinks do you have on a typical day when you are drinking?: Response  \
# 0
# 1                                                  2
# 2
# 3                                                  1
# 4                                                  1
#
#   Do you, or have you ever, smoked cigarettes, cigars, pipes or any other tobacco products?: Response  \
# 0
# 1                                                  3
# 2
# 3                                                  2
# 4                                                  2
#
#   Have you ever been involved in occupations that require you to mix, apply or load any pesticides, herbicides, weed killers, fumigants or fungicides?: Response  \
# 0
# 1                                                  2
# 2
# 3                                                  2
# 4                                                  2
#
#   On average, how many hours per night do you sleep?: Open-Ended Response  \
# 0
# 1                                                6-8
# 2
# 3                                                  7
# 4                                                  8
#
#   Write a short sketch about a memory from your childhood and why it is memorable or important to you. Feel free to discuss an event with family or friends, a place you traveled, or a significant time in your life.  Please limit your response to no more than 1-2 paragraphs.  This question is optional.: Open-Ended Response  \
# 0
# 1
# 2
# 3  I remember traveling to the National Parks wit...
# 4  When I was 8 I swam across a little lake and w...
#
#   How does technology and social media impact the daily lives of you and your family?Please limit your response to no more than 1-2 paragraphs.  This question is optional.: Open-Ended Response  \
# 0
# 1
# 2
# 3  I like using technology and overcoming the dif...
# 4  I keep in touch with friends and family, do re...
#
#   uid: Open-Ended Response joined: Open-Ended Response  \
# 0                    28350                  1505831996
# 1                    34727                  1507164531
# 2                    46314                  1519250996
# 3                    46294                  1519049573
# 4                    46308                  1519246474
#
#   email: Open-Ended Response lc: Open-Ended Response
# 0                                                 10
# 1                                                  3
# 2                                                 10
# 3                                                  5
# 4                                                 10
#
# [5 rows x 129 columns]

# %%
transformed_header_row
# Out:
# ['Respondent ID: ',
#  'Collector ID: ',
#  'Start Date: ',
#  'End Date: ',
#  'IP Address: ',
#  'Email Address: ',
#  'First Name: ',
#  'Last Name: ',
#  'Custom Data 1: ',
#  'How many lessons did you complete on AlzU.org?: Response',
#  'Please select the reasons why you have not yet completed the full 10 lesson course on AlzU.org. Select ALL that apply: Response',
#  'Please select the reasons why you have not yet completed the full 10 lesson course on AlzU.org. Select ALL that apply: Other (please specify)',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Saw a doctor to discuss ways to lower AD risk?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Participated in an AD prevention research study other than this one?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Saw a doctor to be evaluated for memory loss?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Saw a doctor to discuss ways to prevent memory loss?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Saw a doctor to discuss an AD research study for a family member or friend?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Was screened for, or enrolled in, an AD prevention clinical trial?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Was screened for, or enrolled in, the Early Study AD prevention clinical trial?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Was screened for, or enrolled in, the Generation Study AD prevention clinical trial?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Joined the AD prevention registry endALZnow.org?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Joined the AD prevention registry BrainHealthRegistry.org?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Joined the Global Alzheimer\'s Platform "TRC PAD" AD prevention registry?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Made a dietary change to improve my brain health?',
#  'Below are listed several behaviors related to AD. Thinking back over the past three months, please indicate to what extent you have thought about or already done something related to the following behaviors:: Increased exercise to improve my brain health?',
#  'What would you be willing to do or to undergo in order to learn about your risk for developing AD someday in the future?: Take tests of my thinking and memory.',
#  'What would you be willing to do or to undergo in order to learn about your risk for developing AD someday in the future?: Get a blood test.',
#  'What would you be willing to do or to undergo in order to learn about your risk for developing AD someday in the future?: Get a brain scan (picture of the brain, like an MRI or cat scan).',
#  'What would you be willing to do or to undergo in order to learn about your risk for developing AD someday in the future?: Get a genetic test to determine whether I have an Alzheimer\xe2\x80\x99s risk gene.',
#  'Please rate how likely it is that you would participate in the following types of AD research studies:: Requires answering questions on a computer and taking tests of memory skills?',
#  'Please rate how likely it is that you would participate in the following types of AD research studies:: Randomly assigns half to receive a medicine and the other half to receive an inactive version?',
#  'Please rate how likely it is that you would participate in the following types of AD research studies:: Randomly assigns half to make a dietary and exercise change, and the other half to continue as usual?',
#  'Please rate how helpful or harmful each of the following would be.: Seeing your doctor to discuss ways to lower AD risk',
#  'Please rate how helpful or harmful each of the following would be.: Participate in an AD prevention research study',
#  'Please rate your level of agreement with the following questions.: There is a strong possibility that I will develop AD',
#  'Please rate your level of agreement with the following questions.: Changing my lifestyle and health habits can help me reduce my chance of developing AD',
#  'Please rate your level of agreement with the following questions.: I have a lot to gain by changing my lifestyle and health behavior',
#  'Please rate your level of agreement with the following questions.: I feel that my chances of developing AD in the future are high',
#  'Please rate your level of agreement with the following questions.: I am too busy to change my lifestyle and health habits',
#  'Please rate your level of agreement with the following questions.: Family responsibilities make it hard for me to change my lifestyle and behavior',
#  'Please rate your level of agreement with the following questions.: When I think about AD my heart beats faster',
#  'Please rate your level of agreement with the following questions.: When I think about AD I feel nauseous',
#  'Please rate your level of agreement with the following questions.: The thought of AD scares me',
#  'Please rate your level of agreement with the following questions.: Changing lifestyle and behavior interferes with my schedule',
#  'Please rate your level of agreement with the following questions.: My chances of developing AD are great.',
#  'Please rate your level of agreement with the following questions.: I am certain that I can change my lifestyle and behavior so I can reduce the risk of developing AD',
#  'How much do you weigh without your clothes and shoes\xc2\xa0in pounds?: Open-Ended Response',
#  'Have you ever been told by a doctor or other health professional that you have diabetes or have high sugar levels in your blood or urine?: Response',
#  'Have you ever been told by a doctor or other health professional that you have high cholesterol levels in the past 2 years or your cholesterol level is higher than 240mg/dL?: Response',
#  'If you recall your most recent cholesterol results, please enter here:: Total Cholesterol',
#  'If you recall your most recent cholesterol results, please enter here:: LDL ("bad" cholesterol)',
#  'If you recall your most recent cholesterol results, please enter here:: HDL ("good" cholesterol)',
#  'If you recall your most recent cholesterol results, please enter here:: Triglycerides',
#  'If you recall your most recent blood pressure, please enter here. This is recorded as a two numbers, e.g., 130/80. Please enter the larger number (called Systolic) first, and the smaller number (called Diastolic), second.: Systolic Blood Pressure',
#  'If you recall your most recent blood pressure, please enter here. This is recorded as a two numbers, e.g., 130/80. Please enter the larger number (called Systolic) first, and the smaller number (called Diastolic), second.: Diastolic Blood Pressure',
#  'Have you ever had a head injury where you lost consciousness for more than 15 minutes?: Response',
#  'Check best answer for each description.: I was bothered by things that usually don\xe2\x80\x99t bother me.',
#  'Check best answer for each description.: I had trouble keeping my mind on what I was doing.',
#  'Check best answer for each description.: I felt depressed.',
#  'Check best answer for each description.: I felt that everything I did was an effort.',
#  'Check best answer for each description.: I felt\xc2\xa0hopeful about the future.',
#  'Check best answer for each description.: I felt fearful.',
#  'Check best answer for each description.: My sleep was restless.',
#  'Check best answer for each description.: I was happy.',
#  'Check best answer for each description.: I felt lonely.',
#  'Check best answer for each description.: I could not \xe2\x80\x9cget going\xe2\x80\x9d',
#  'During the last 7 days, on how many days did you do vigorous physical activities like heavy lifting, digging, aerobics, or fast bicycling? Think about only those physical activities that you did for at least 10 minutes at a time. Please answer in\xc2\xa0days per week.: Open-Ended Response',
#  'How much time in total did you usually spend on one of those days doing vigorous physical activities? Please answer in\xc2\xa0minutes per day.: Open-Ended Response',
#  'Again, think only about those physical activities that you did for at least 10 minutes at a time. During the last 7 days, on how many days did you do moderate physical activities like carrying light loads, bicycling at a regular pace, or double tennis? Please do not include walking, and please answer in\xc2\xa0days per week.: Open-Ended Response',
#  'How much time in total did you usually spend on one of those days doing moderate physical activities? Please answer in\xc2\xa0minutes\xc2\xa0per day.: Open-Ended Response',
#  'During the last 7 days, on how many days did you walk for at least 10 minutes at a time? This includes walking at work and at home, walking to travel from place to place, and any other walking that you did solely for recreation, sport, exercise or leisure. Please answer in\xc2\xa0days per week.: Open-Ended Response',
#  'How much time in total did you usually spend walking on one of those days? Please answer in\xc2\xa0minutes per day.: Open-Ended Response',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I rarely or never do any physical activities',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I do some light or moderate physical activities, but not every week',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I do some light physical activity every week',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I do moderate physical activities every week, but less than 30 minutes a day or 5 days a week',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I do vigorous physical activities every week, but less than 20 minutes a day or 3 days a week',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I do 30 minutes or more a day of moderate physical activities, 5 or more days a week',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I do 20 minutes or more a day of vigorous physical activities, 3 or more days a week',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I do activities to increase muscle strength, such as lifting weights or calisthenics, once a week or more',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: I do activities to improve flexibility, such as stretching or yoga, once a week or more',
#  'These questions ask about the amount and intensity of physical activity that you usually do.: Other (please specify more comments about any of your answers above)',
#  'During the past year, how much time did you spend reading each day, including online reading?: hours per day:',
#  'During the\xc2\xa0past year, how often were you engaging in...: Reading books (including online)',
#  'During the\xc2\xa0past year, how often were you engaging in...: Reading newspaper\xc2\xa0(including online)',
#  'During the\xc2\xa0past year, how often were you engaging in...: Reading magazines\xc2\xa0(including online)',
#  'During the\xc2\xa0past year, how often were you engaging in...: Playing games (word game, checkers, mind teasers, etc)',
#  'During the\xc2\xa0past year, how often were you engaging in...: Writing letters or emails',
#  'During the\xc2\xa0past year, how often were you engaging in...: Use online social network activities',
#  'During the\xc2\xa0past year, how often were you engaging in...: Participating in \xe2\x80\x98brain training\xe2\x80\x99 activities',
#  'During the\xc2\xa0past year, how often were you engaging in...: Visiting a museum',
#  'During the\xc2\xa0past year, how often were you engaging in...: Attending a concert, play or musical',
#  'During the\xc2\xa0past year, how often were you engaging in...: Visiting a library',
#  'How many of your friends do you see or hear from at least once a month?: Response',
#  'Are you satisfied with your relationships with friends and relatives?: Response',
#  'How often do you participate in religious services or social, political or community groups?: Response',
#  'Do you live alone or with other people?: Response',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Green Leafy Vegetables (1 cup leafy, 1/2 c. for cooked/raw chopped)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Other Vegetables (1/2 c, e.g. broccoli, carrots, string beans)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Berries (1/2 c, e.g. strawberries, blueberries)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Other Fruits (1/2 c)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Nuts (handful or 1/4-1/3 c.)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Olive oil (1 tbs.)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Butter, Cream (1 tablespoon)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Regular Cheese (1 oz.)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Whole grains (1 slice bread, 3/4 cup pasta/cereal)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Fish (3 oz, not fried, not shell)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Beans (1/2 c.)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Poultry (3 oz, not fried)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Red meat (3 oz steak, ham, burgers)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Fast foods',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Pastries & Sweets',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Wine (glasses per week; 1 glass = 5 oz)',
#  'How many servings of each of the following foods do you have per week? Enter a numerical value or zero.: Other alcohol (serving = 1.5 oz liquor or 12 oz beer)',
#  'On average, what percent of your diet is made up of carbohydrates?: Response',
#  'How many nights per week do you fast (meaning no calories at all) from dinner until breakfast lasting at least ~12 hours? (Please enter a number from 0-7): Open-Ended Response',
#  'In the\xc2\xa0past 12 months, how often did you eat fish or seafood that is not fried?: Response',
#  '<https://www.alzu.org/assets/images/alcohol-volume.PNG>: Response',
#  '<https://www.alzu.org/assets/images/alcohol-volume.PNG>: Other (please specify)',
#  'How many drinks do you have on a typical day when you are drinking?: Response',
#  'Do you, or have you ever, smoked cigarettes, cigars, pipes or any other tobacco products?: Response',
#  'Have you ever been involved in occupations that require you to mix, apply or load any pesticides, herbicides, weed killers, fumigants or fungicides?: Response',
#  'On average, how many hours per night do you sleep?: Open-Ended Response',
#  'Write a short sketch about a memory from your childhood and why it is memorable or important to you. Feel free to discuss an event with family or friends, a place you traveled, or a significant time in your life. \xc2\xa0Please limit your response to no more than 1-2 paragraphs.\xc2\xa0 This question is optional.: Open-Ended Response',
#  'How does technology and social media impact the daily lives of you and your family?Please limit your response to no more than 1-2 paragraphs.\xc2\xa0 This question is optional.: Open-Ended Response',
#  'uid: Open-Ended Response',
#  'joined: Open-Ended Response',
#  'email: Open-Ended Response',
#  'lc: Open-Ended Response']
